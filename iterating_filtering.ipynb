# %%
import pandas as pd

df=pd.read_csv("data/cafeitems.csv")
menu=df

# %%
for index,row in menu.iterrows():
    print(index)
    print(row)
# Out:
# 0
# id                          6
# name           White Espresso
# category             Beverage
# price                  999999
# stock                  999999
# created_at    1/08/1909 11:00
# Name: 0, dtype: object
# 1
# id                          6
# name                 Espresso
# category             Beverage
# price                       3
# stock                      30
# created_at    1/08/2025 11:00
# Name: 1, dtype: object
# 2
# id                                 7
# name          Flat White and a scone
# category          Beverage and Snack
# price                   4.2 and 3.92
# stock                      25 and 12
# created_at           1/08/2025 11:00
# Name: 2, dtype: object
# 3
# id                           8
# name          Blueberry Muffin
# category                Pastry
# price                      3.8
# stock                       15
# created_at     1/08/2025 11:00
# Name: 3, dtype: object
# 4
# id                          9
# name                    Bagel
# ...
